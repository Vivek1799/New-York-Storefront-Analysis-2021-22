# %%
import pandas as pd
df = pd.read_excel("/Users/vivekravipatil/Desktop/New-York-Storefront-Vacancy-Report-2022/data/vacancy_by_nbhd.xlsx")
df
# Out:
#      Unnamed: 0      BOROUGH 1                                  NBHD  \
# 0           265       BROOKLYN            park-cemetery-etc-Brooklyn
# 1           301      MANHATTAN               Turtle Bay-East Midtown
# 2           363         QUEENS  Springfield Gardens South-Brookville
# 3           394         QUEENS                              Glendale
# 4           319      MANHATTAN     Battery Park City-Lower Manhattan
# ..          ...            ...                                   ...
# 579         450         QUEENS                             Bellerose
# 580         358         QUEENS             Springfield Gardens North
# 581         563  STATEN ISLAND                     Rossville-Woodrow
# 582         110          BRONX               park-cemetery-etc-Bronx
# 583         578  STATEN ISLAND                         Arden Heights
#
#     Reporting Year        pct  num_storefornts
# 0    2021 and 2022  54.285714               35
# ...

# %%
df2 = pd.read_csv("/Users/vivekravipatil/Desktop/New-York-Storefront-Vacancy-Report-2022/data/Storefront_Registration_Class_2_and_4_Statistics.csv")
df2
# Out:
#       Reporting Year  \
# 0               2021
# 1               2021
# 2               2021
# 3               2021
# 4               2021
# ...              ...
# 4497            2019
# 4498            2019
# 4499            2019
# 4500            2019
# 4501            2019
#
#      Aggregate Level (Citywide, Borough, Council District, Census Tract)  \
# 0                                              Citywide
# 1                                          Census Tract
# 2                                          Census Tract
# 3                                          Census Tract
# 4                                          Census Tract
# ...                                                 ...
# 4497                                       CENSUS TRACT
# 4498                                       CENSUS TRACT
# 4499                                       CENSUS TRACT
# 4500                                       CENSUS TRACT
# 4501                                       CENSUS TRACT
#
# ...

# %%
#filter the df to only include Manhattan

df = df[df['BOROUGH 1'] == 'MANHATTAN']

# %%
df
# Out:
#      Unnamed: 0  BOROUGH 1                                         NBHD  \
# 1           301  MANHATTAN                      Turtle Bay-East Midtown
# 4           319  MANHATTAN            Battery Park City-Lower Manhattan
# 7           298  MANHATTAN                        Midtown-Midtown South
# 9           349  MANHATTAN               Stuyvesant Town-Cooper Village
# 11          289  MANHATTAN  Hudson Yards-Chelsea-Flat Iron-Union Square
# ..          ...        ...                                          ...
# 514         290  MANHATTAN                               Lincoln Square
# 518         332  MANHATTAN                            East Harlem South
# 546         275  MANHATTAN                               Manhattanville
# 554         266  MANHATTAN                           Marble Hill-Inwood
# 563         278  MANHATTAN                          Morningside Heights
#
#     Reporting Year        pct  num_storefornts
# 1    2021 and 2022  19.800182             1101
# ...

# %%
df.to_csv("mahattan.csv")

# %%
#here we import R 

# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings
# Out:
# During startup - Warning messages:
# 1: Setting LC_COLLATE failed, using "C"
# 2: Setting LC_TIME failed, using "C"
# 3: Setting LC_MESSAGES failed, using "C"
# 4: Setting LC_MONETARY failed, using "C"

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.0     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.1     ✔ tibble    3.1.8
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# %%R
#
# data <- read_csv("/Users/vivekravipatil/Desktop/New-York-Storefront-Vacancy-Report-2022/data/mahattan.csv")
# Out:
# New names:
# • `` -> `...1`
# Rows: 85 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): BOROUGH 1, NBHD, Reporting Year
# dbl (4): ...1, Unnamed: 0, pct, num_storefornts
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# %%R
# head(data)
# Out:
# # A tibble: 6 × 7
#    ...1 `Unnamed: 0` `BOROUGH 1` NBHD                      Repor…¹   pct num_s…²
#   <dbl>        <dbl> <chr>       <chr>                     <chr>   <dbl>   <dbl>
# 1     1          301 MANHATTAN   Turtle Bay-East Midtown   2021 a…  19.8    1101
# 2     4          319 MANHATTAN   Battery Park City-Lower … 2021 a…  19.1     755
# 3     7          298 MANHATTAN   Midtown-Midtown South     2021 a…  18.0    3055
# 4     9          349 MANHATTAN   Stuyvesant Town-Cooper V… 2021 a…  16.7      24
# 5    11          289 MANHATTAN   Hudson Yards-Chelsea-Fla… 2021 a…  16.4    1760
# 6    13          316 MANHATTAN   SoHo-TriBeCa-Civic Cente… 2021 a…  15.9    2116
# # … with abbreviated variable names ¹​`Reporting Year`, ²​num_storefornts

# %%
# %%R
# colnames(data)
# Out:
# [1] "...1"            "Unnamed: 0"      "BOROUGH 1"       "NBHD"
# [5] "Reporting Year"  "pct"             "num_storefornts"

# %%
df
# Out:
#      Unnamed: 0  BOROUGH 1                                         NBHD  \
# 1           301  MANHATTAN                      Turtle Bay-East Midtown
# 4           319  MANHATTAN            Battery Park City-Lower Manhattan
# 7           298  MANHATTAN                        Midtown-Midtown South
# 9           349  MANHATTAN               Stuyvesant Town-Cooper Village
# 11          289  MANHATTAN  Hudson Yards-Chelsea-Flat Iron-Union Square
# ..          ...        ...                                          ...
# 514         290  MANHATTAN                               Lincoln Square
# 518         332  MANHATTAN                            East Harlem South
# 546         275  MANHATTAN                               Manhattanville
# 554         266  MANHATTAN                           Marble Hill-Inwood
# 563         278  MANHATTAN                          Morningside Heights
#
#     Reporting Year        pct  num_storefornts
# 1    2021 and 2022  19.800182             1101
# ...

# %%
#
